# %%
import nltk.book
from nltk.book import *
nltk.download('book', quiet = True)

from nltk.corpus import gutenberg
nltk.download('gutenberg', quiet = True)

from nltk.corpus import brown
nltk.download('brown', quiet = True)
# Out:
# True

# %%
brown = nltk.corpus.brown

cfd = nltk.ConditionalFreqDist(

    (genre, modals)
    for genre in brown.categories()
    
    for modals in ['can', 'could', 'will', 'would', 'may', 'might']
    
    for word in brown.words(categories = genre)
        if word.lower() == modals
)

cfd.tabulate()
# Out:
#                   can could   may might  will would
#       adventure    48   154     7    59    51   194
#  belles_lettres   249   216   221   113   246   397
#       editorial   124    57    79    39   235   185
#         fiction    39   168    10    44    56   291
#      government   119    38   179    13   244   120
#         hobbies   276    59   143    22   269    83
#           humor    17    33     8     8    13    56
#         learned   367   159   336   128   340   321
#            lore   170   142   170    50   178   188
#         mystery    45   145    15    57    25   189
#            news    94    87    93    38   389   246
#        religion    84    59    79    12    72    69
#         reviews    45    40    47    26    61    48
#         romance    79   195    11    51    49   247
# science_fiction    16    49     4    12    17    80

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
cfd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
inaugural = nltk.corpus.inaugural

cfd = nltk.ConditionalFreqDist(

    (fileid[:-4], target_word)
    
    for fileid in inaugural.fileids()
    for target_word in ['president', 'history', 'korea']
    for word in inaugural.words(fileid)
        if word.lower().startswith(target_word)
)

cfd.tabulate()
# Out:
#                   history     korea president
# 1789-Washington         0         0         1
# 1793-Washington         0         0         1
#      1797-Adams         1         0         0
#  1801-Jefferson         2         0         0
#  1805-Jefferson         2         0         0
#     1817-Monroe         1         0         0
#    1833-Jackson         0         0         1
#   1837-VanBuren         2         0         2
#   1841-Harrison         2         0        14
#       1845-Polk         0         0         2
#     1849-Taylor         1         0         3
#     1853-Pierce         4         0         0
#   1857-Buchanan         4         0         2
#    1861-Lincoln         1         0         2
#    1865-Lincoln         0         0         1
#      1869-Grant         0         0         1
#      1873-Grant         1         0         1
#      1877-Hayes         3         0         5
#   1881-Garfield         2         0         0
# ...

# %%
cfd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
cfd = nltk.ConditionalFreqDist(
    (target_word, fileid[:-4])
    
    for fileid in inaugural.fileids()
    
    for target_word in ['president', 'history', 'korea']
    
    for word in inaugural.words(fileids=fileid)
        if word.lower().startswith(target_word)
)


import matplotlib.pyplot as plt
plt.figure(figsize=(12,5))
cfd.plot()
# Out:
# <AxesSubplot:xlabel='Samples', ylabel='Counts'>

# %%
hufs = ['eicc', 'elc', 'ellt']
hufs.append('social science')
hufs.extend('computer science') # extend 는 리스트를 병합하는 함수. 즉 이렇게 문자열을 넣으면 각 글자들이 들어감
hufs.remove('elc')
del hufs[0]
hufs.pop()
hufs
# Out:
# ['ellt',
#  'social science',
#  'c',
#  'o',
#  'm',
#  'p',
#  'u',
#  't',
#  'e',
#  'r',
#  ' ',
#  's',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c']

# %%
hufs.append(['korean', 'spanish', 'japanese'])
hufs[-1][2]
# Out:
# 'japanese'

# %%
hufs_copy = hufs.copy()
hufs.clear()
hufs_copy
# Out:
# ['ellt',
#  'social science',
#  'c',
#  'o',
#  'm',
#  'p',
#  'u',
#  't',
#  'e',
#  'r',
#  ' ',
#  's',
#  'c',
#  'i',
#  'e',
#  'n',
#  'c',
#  ['korean', 'spanish', 'japanese']]

# %%
lang = ['python', 'c', 'java']
cs = ['data structure', 'ai', 'os']

for itemA, itemB in zip(lang, cs):
    print((itemA, itemB))
# Out:
# ('python', 'data structure')
# ('c', 'ai')
# ('java', 'os')

# %%
sentence = "don't judge a book by its cover"
# (대문자, 타이틀, 글자수) 형태로 저장된 리스트 만들어라.


[(word.upper(), word.title(), len(word)) for word in sentence.split()]
# Out:
# [("DON'T", "Don'T", 5),
#  ('JUDGE', 'Judge', 5),
#  ('A', 'A', 1),
#  ('BOOK', 'Book', 4),
#  ('BY', 'By', 2),
#  ('ITS', 'Its', 3),
#  ('COVER', 'Cover', 5)]

# %%
text = [
    ['hello', 'guys'],
    ['how', 'are', 'you']
]


sent_list = [" ".join(list) for list in text]
word_list = [word for list in text for word in list]
entire_str = " ".join([word for list in text for word in list])

# %%
print(sent_list)
print(word_list)
print(entire_str)
# Out:
# ['hello guys', 'how are you']
# ['hello', 'guys', 'how', 'are', 'you']
# hello guys how are you

# %%
cl = ('client', ['alex', True])
em = ('employee', ['john', False])
info = cl, em
info
# Out:
# (('client', ['alex', True]), ('employee', ['john', False]))
